# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tmdb_movies_data.csv')

# %%
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
x = np.random.rand(500)
plt.hist(x,5);
plt.show()

# %%
x = np.random.rand(500,5)
x
# Out:
# array([[0.87988854, 0.41275358, 0.88780474, 0.84983828, 0.45867124],
#        [0.83611436, 0.37221285, 0.89297852, 0.93573075, 0.48398307],
#        [0.55052552, 0.11825925, 0.13293569, 0.48835195, 0.14294376],
#        ...,
#        [0.96579924, 0.60856583, 0.63948301, 0.88125814, 0.03586517],
#        [0.10576803, 0.39543149, 0.28025479, 0.45298946, 0.34242683],
#        [0.6099767 , 0.13277227, 0.48163924, 0.47857123, 0.80262964]])

# %%
bins_arr = list(range(0,11,2))
plt.hist(df["vote_average"],bins=bins_arr,facecolor='g',edgecolor='white');
plt.xlabel('Vote Average')
plt.ylabel('Frequency')
plt.title("Dist of Vote Avrg")
plt.show()

# %%
df["vote_average"].max()
# Out:
# 9.2

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]
plt.plot(x,y)
plt.plot(y,x)

# %%
movie_count = pd.DataFrame(df.release_year.value_counts(ascending=True))
movie_count = movie_count.reset_index()

# %%
movie_count.columns = ['year','count']
movie_count.head()
# Out:
#    year  count
# 0  1969     31
# 1  1961     31
# 2  1962     32
# 3  1960     32
# 4  1963     34

# %%
movie_count = movie_count.sort_values(by=['year'])

# %%
movie_count.head()
# Out:
#     year  count
# 3   1960     32
# 1   1961     31
# 2   1962     32
# 4   1963     34
# 10  1964     42

# %%
plt.plot(movie_count['year'],movie_count['count'],c="red",marker='|');
plt.xlabel("Years")
plt.ylabel("Movie counts")
plt.title("Released movies annually")
plt.xlim(1960,2015)
plt.xticks(range(1960,2016,5))
plt.legend(['movies'],loc='best')
plt.show()

# %%
plt.bar(np.arange(5),np.arange(5))
# Out:
# <BarContainer object of 5 artists>

# %%
top = df.groupby('original_title').sum().sort_values(by="revenue",ascending=False)
top
# Out:
#                                   id             imdb_id  popularity  \
# original_title
# Avatar                         19995           tt0499549    9.432768
# Star Wars: The Force Awakens  140607           tt2488496   11.173104
# Titanic                         3296  tt0120338tt0115392    4.574583
# The Avengers                   33748  tt0848228tt0118661    8.176900
# Jurassic World                135397           tt0369610   32.985763
# ...                              ...                 ...         ...
# Zwart Water                    42833           tt1223980    0.178450
# eCupid                        105885           tt1754944    0.045198
# iCarly: iGo to Japan           62459           tt1286124    0.077034
# 100 Bloody Acres              126757           tt2290065    0.323242
# Into the Abyss                 77365           tt1972663    0.055256
#
#                                  budget     revenue  \
# original_title
# ...

# %%
movies = top.head().index

# %%
movies
# Out:
# Index(['Avatar', 'Star Wars: The Force Awakens', 'Titanic', 'The Avengers',
#        'Jurassic World'],
#       dtype='object', name='original_title')

# %%
revenue = top.head().revenue.values
revenue
# Out:
# array([2781505847, 2068178225, 1845034188, 1568080742, 1513528810])

# %%
plt.figure(figsize=(10,5))
plt.bar(movies,revenue,color=['blue','g','0.2','red','0.5'])
plt.xlabel("Movie",fontsize=20)
plt.ylabel("Rvenue",fontsize=20)
plt.grid()
plt.title("Best movie's revenue")
# Out:
# Text(0.5, 1.0, "Best movie's revenue")

# %%
plt.pie(np.arange(1,4),labels=['a','b','c'],colors=['red','green','blue']);

# %%
df.head(3)
# Out:
#        id    imdb_id  popularity     budget     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
# 2  262500  tt2908446   13.112507  110000000   295238201           Insurgent
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
#
#                                          homepage          director  \
# 0                   http://www.jurassicworld.com/   Colin Trevorrow
# 1                     http://www.madmaxmovie.com/     George Miller
# 2  http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
#
#                       tagline  ...  \
# 0           The park is open.  ...
# 1          What a Lovely Day.  ...
# 2  One Choice Can Destroy You  ...
#
# ...

# %%
top_genres = df.groupby('genres').sum().sort_values(by='revenue',ascending=False)['revenue'][0:5]

# %%
top_genres
# Out:
# genres
# Comedy                      20323889661
# Drama                       15107533347
# Comedy|Romance              11545724341
# Adventure|Fantasy|Action     7597483556
# Comedy|Drama|Romance         7251175696
# Name: revenue, dtype: int64

# %%
plt.pie(top_genres.values,labels=top_genres.index,startangle=90,radius=1
       ,autopct='%1.3f%%'
       );

# %%
plt.scatter(np.random.randn(500),np.random.randn(500));

# %%
df.head(2)
# Out:
#        id    imdb_id  popularity     budget     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
#
#                         homepage         director             tagline  ...  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow   The park is open.  ...
# 1    http://www.madmaxmovie.com/    George Miller  What a Lovely Day.  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
#
# ...

# %%
plt.scatter(df.vote_average,df.revenue,alpha=0.5,label="average",marker="+",color="red");
plt.scatter(df.vote_count,df.revenue,alpha=0.5,label="count");
plt.legend()
plt.ylabel("Revenue")
plt.xlabel("Vote Averg")
plt.title("Revenue based on bote avrg");

# %%
#chart1
plt.bar(np.arange(1,15),np.arange(1,15));

# %%
#chart2
plt.pie(np.arange(1,4),labels=['a','b','c']);

# %%
#chart3
plt.plot([1,2,3,4,5,6],[1,2,3,4,5,6]);

# %%
plt.hist(np.random.randn(250));
plt.savefig("hist.png",dpi=400)
import os
os.getcwd()
# Out:
# 'C:\\Users\\boulares computer'

# %%
plt.figure(figsize=[10,10]);

plt.suptitle("Sales in Sep 2025")

plt.subplot(2,2,1)
plt.bar(np.arange(1,15),np.arange(1,15));

plt.subplot(2,2,2)
plt.pie(np.arange(1,4),labels=['a','b','c']);

plt.subplot(2,2,3)
plt.plot([1,2,3,4,5,6],[1,2,3,4,5,6]);

plt.subplot(2,2,4)
plt.hist(np.random.randn(250));
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[112], line 17
#      14 plt.subplot(2,2,4)
#      15 plt.hist(np.random.randn(250));
# ---> 17 plt.savefig("..\sales_collection.png",dpi=700)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1243, in savefig(*args, **kwargs)
#    1240 fig = gcf()
#    1241 # savefig default implementation has no return, so mypy is unhappy
#    1242 # presumably this is here because subclasses can return?
# -> 1243 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1244 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1245 return res
#
# File ~\anaconda3\Lib\site-packages\matplotlib\figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# ...
