# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
tips.tail(3)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
diamonds = sns.load_dataset("diamonds")

# %%
sns.displot(tips,x="total_bill",kde=True,col="sex");

# %%
sns.countplot(diamonds,x="clarity");

# %%
plt.pie(tips.smoker.value_counts(),labels=tips.smoker.value_counts().index);

# %%
tips.smoker.value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
#sns.lineplot(data=tips,x='tip',y='size');
sns.scatterplot(data=tips,y='tip',x='total_bill');

# %%
sns.barplot(data=tips,x="day",y="total_bill",hue="sex");

# %%
sns.histplot(diamonds.sort_values('clarity').reset_index(),x='clarity',hue='cut',
             multiple="stack");

# %%
diamonds.head(3)
#sns.swarmplot(tips,x="time",y="tip");
#sns.swarmplot(diamonds.head(20),x="color",y="price");
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="smoker");

# %%
sns.catplot(tips,x="time",y="total_bill",kind="bar",col="day",hue="sex");
